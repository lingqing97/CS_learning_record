# %% [markdown]
# ### 多层感知机

# %% [markdown]
# #### 隐藏层
#
# 多层感知机在单层神经网络的基础上引入了一到多个隐藏层(hidden layer)。
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 激活函数
#
# 上述问题的根源在于全连接层只是对数据做访射变换，而多个访射变换的叠加仍然是一个访射变换。解决问题的一个方法是引入非线性变换。这个非线性变换函数被称为激活函数。

# %% [markdown]
# ##### ReLU函数
#
# ReLU函数提供了一个很简单的非线性变换。给定元素x，该函数定义为:
# $ReLU(x)=max(x,0)$
# ![image.png](attachment:image.png)

# %% [markdown]
# 显然当输入为负数时，ReLU函数的导数为0；当输入为正数时，ReLU函数的导数为1.尽管输入为0时ReLU函数不可导，但是我们可以取此处的导数为0。下面绘制ReLU函数的导数。
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### sigmoid函数
#
# sigmoid函数可以将元素的值变换到0和1之间:
#
# $sigmoid(x)=\frac{1}{1+exp(-x)}$
#
# sigmodi函数在早期的神经网络中较普遍，但目前逐渐被简单的ReLU函数取代.
# ![image.png](attachment:image.png)

# %% [markdown]
# 当输入为0时，sigmoid函数的导数达到最大值0.25;当输入越偏离0时,sigmoid函数的导数越接近0.
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### tanh函数
#
# tanh(双曲正切)函数可以将元素的值变换到-1到1之间:
#
# $tanh(x)=\frac{1-exp(-2x)}{1+exp(-2x)}$
#
# tanh函数在坐标系上关于原点对称.
# ![image.png](attachment:image.png)

# %% [markdown]
# 当输入为0时，tanh函数的导数达到最大值1；当输入越偏离0时，tanh函数的导数越接近0.
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 多层感知机
#
# ![image.png](attachment:image.png)
