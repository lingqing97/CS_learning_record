# %% [markdown]
# ### 含并行连结的网络(GoogLeNet)
#
# GoogLeNet中的基础卷积块叫做Inception块，其结构如下:
# ![image.png](attachment:image.png)
#
# Inception块中有4条并行的线路。4条线路使用了合适的填充来使输入与输出的高和宽一致。最后将每条线路的输出在通道维上连结。
#
# Inception使用1x1卷积层来改变通道数，从而降低模型的复杂度。
